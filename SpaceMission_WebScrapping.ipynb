# %% [markdown]
# # Space Mission Data - Web Scrapping from Next Space Flight Website

# %% [markdown]
# **Team Member - Ashina Neema**

# %% [markdown]
# **Task Goal**:
# The aim of this task is to collect information about space missions conducted in the past from a website called https://nextspaceflight.com/. I'm interested in gathering details like the name of the space mission, its launch date, location, mission status, the organization behind it, rocket status, and the price of the mission.

# %% [markdown]
# **Learning & Credits**: For learning how to scrape data from websites, I took guidance from Professor Mark Isken's course -
# 1. PCDA - http://www.sba.oakland.edu/faculty/isken/courses/mis5470_f23/index.html
#
# 2. Advance Analytics with python - http://www.sba.oakland.edu/faculty/isken/courses/aap/
#
# Additionally, I gained valuable insights into web scraping techniques from the Udemy course "100 Days of Code." https://www.udemy.com/course/100-days-of-code/
#
# I understood fundamental web scraping concepts, including HTML parsing and BeautifulSoup library usage for efficient data extraction. It was challenging but worth it!

# %% [markdown]
# # Task 1 : Web Scrapping

# %%
from bs4 import BeautifulSoup
import requests
import csv


total_pages = 221
limit = 30
complete_data = []
for page_number in range(1, total_pages + 1):
    url = f"https://nextspaceflight.com/launches/past/?page={page_number}"
    response = requests.get(url)
    space_page = response.text

    soup = BeautifulSoup(space_page, "html.parser")

    space_mission = soup.find_all(name="h5", class_="header-style")
    space_mission_texts = []
    for space_mission_tag in space_mission:
        space_mission_text = space_mission_tag.getText()
        space_mission_texts.append(space_mission_text)

    space_mission_list = [mission.strip() for mission in space_mission_texts]

    launch_date_org_tag = [item.getText() for item in soup.find_all(class_="mdl-card__supporting-text")]
    cleaned_launch_date_org_tag = [item.strip() for item in launch_date_org_tag]

    date_list = [item.split('\n')[0].strip() for item in cleaned_launch_date_org_tag]
    location_list = [item.split('\n')[1].strip() for item in cleaned_launch_date_org_tag]

    # Use zip to combine the three lists
    space_mission_data = [{'Space Mission': mission, 'Date': date, 'Location': location}
                          for mission, date, location in zip(space_mission_list, date_list, location_list)]

    # Print or use the list of dictionaries
    # print(type(space_mission_data))

    results_list = []

    # Set the limit for the loop

    counter = 0

    for button_element in soup.find_all('button', {'class': 'mdc-button'}):
        onclick_value = button_element.get('onclick')
        if onclick_value and 'location.href' in onclick_value:

            link = onclick_value.split('=')[1].strip().strip("'")
            Base_url = 'https://nextspaceflight.com'
            details_url = Base_url + link
            details_response = requests.get(details_url)
            details_html_content = details_response.text

            details_soup = BeautifulSoup(details_html_content, 'html.parser')

            h6_element = details_soup.find(name='h6', class_='rcorners status')
            # Find the span element inside the h6 element
            span_element = h6_element.find('span')
            # Extract the text content of the span element
            mission_status = span_element.text.strip()

            org = details_soup.find(name='div', class_='mdl-cell mdl-cell--6-col-desktop mdl-cell--12-col-tablet').text.strip()

            # Find the div containing 'Rocket Status:'
            rocket_status_div = details_soup.find(name='div', class_='mdl-cell mdl-cell--6-col-desktop mdl-cell--12-col-tablet',
                                           string=lambda t: t and 'Status:' in t)
            rocket_status = rocket_status_div.text.replace('Status:', '').strip() if rocket_status_div else None

            # Find the div containing 'Price:'
            price_div = details_soup.find(name='div', class_='mdl-cell mdl-cell--6-col-desktop mdl-cell--12-col-tablet',
                                            string=lambda t: t and 'Price:' in t)
            price = price_div.text.replace('Price:', '').replace('$', '').replace('million', '').strip() if price_div else None

            result_dict = {
                'Mission Status': mission_status,
                'Organization': org,
                'Rocket Status': rocket_status,
                'Price': price
            }

            results_list.append(result_dict)

            # Increment the counter
            counter += 1

            # Check if the limit is reached
            if counter >= limit:
                break

    # Iterate over both lists simultaneously
    for space_dict, other_dict in zip(space_mission_data, results_list):
        # Merge dictionaries for corresponding missions
        merged_dict = {**space_dict, **other_dict}
        complete_data.append(merged_dict)

# Print or use the complete_data list of dictionaries
for data in complete_data:
    print(data)

# Specify the CSV file name
csv_file_name = 'Space_Missions.csv'

# Specify the field names (keys in the dictionaries)
field_names = complete_data[0].keys()

# Write to CSV with 'utf-8' encoding
with open(csv_file_name, mode='w', newline='', encoding='utf-8') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=field_names)

    # Write header
    writer.writeheader()

    # Write data
    for row in complete_data:
        writer.writerow(row)
# Out:
# {'Space Mission': 'Long March 2D | Yaogan 39 Group 05', 'Date': 'Sun Dec 10, 2023 01:58 UTC', 'Location': 'LC-3, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'ZhuQue-2 | Flight 3', 'Date': 'Fri Dec 08, 2023 23:39 UTC', 'Location': 'Site 96, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'Landspace', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-8', 'Date': 'Fri Dec 08, 2023 08:03 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-33', 'Date': 'Thu Dec 07, 2023 05:07 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Jielong-3 | SatNet test satellite', 'Date': 'Tue Dec 05, 2023 19:24 UTC', 'Location': 'Bo Run Jiu Zhou Barge, Chinese Coastal Waters', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Ceres-1 | We Won’t Stop', 'Date': 'Mon Dec 04, 2023 23:33 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'Galactic Energy', 'Rocket Status': 'Active', 'Price': '4.9'}
# {'Space Mission': 'South Korean ADD Solid-Fuel SLV (3 stage) | S-STEP', 'Date': 'Mon Dec 04, 2023 05:00 UTC', 'Location': 'ADD Offshore launch platform, Jeju Island, South Korea', 'Mission Status': 'Success', 'Organization': 'ADD', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Long March 2C | MisrSat-2', 'Date': 'Mon Dec 04, 2023 04:10 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.8'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-31', 'Date': 'Sun Dec 03, 2023 04:00 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | 425 Project Flight 1 and ride-shares', 'Date': 'Fri Dec 01, 2023 18:19 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1a | Progress MS-25', 'Date': 'Fri Dec 01, 2023 09:25 UTC', 'Location': 'Site 31/6, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '17.42'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-30', 'Date': 'Tue Nov 28, 2023 04:20 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1b | Cosmos 2572', 'Date': 'Sat Nov 25, 2023 20:58 UTC', 'Location': 'Site 43/4, Plesetsk Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'VKS RF', 'Rocket Status': 'Active', 'Price': '20.0'}
# {'Space Mission': 'Long March 2D/YZ-3 | 3 x SatNet test satellites', 'Date': 'Thu Nov 23, 2023 10:00 UTC', 'Location': 'LC-3, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-29', 'Date': 'Wed Nov 22, 2023 07:47 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Chŏllima 1 | Manligyeong 1 #3', 'Date': 'Tue Nov 21, 2023 13:42 UTC', 'Location': 'Pad 2, Sohae Satellite Launching Station, North Korea', 'Mission Status': 'Success', 'Organization': 'NADA', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-7', 'Date': 'Mon Nov 20, 2023 10:30 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Starship-Super Heavy (Prototype) | Starship Flight Test 2', 'Date': 'Sat Nov 18, 2023 13:02 UTC', 'Location': 'Orbital Launch Pad A, Starbase, Texas, USA', 'Mission Status': 'Partial Failure', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-28', 'Date': 'Sat Nov 18, 2023 05:05 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2C/YZ-1S | Haiyang 3-01', 'Date': 'Thu Nov 16, 2023 03:55 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.8'}
# {'Space Mission': 'Falcon 9 Block 5 | O3b mPOWER 5 & 6', 'Date': 'Sun Nov 12, 2023 21:08 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Transporter 9', 'Date': 'Sat Nov 11, 2023 18:49 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | CRS SpX-29', 'Date': 'Fri Nov 10, 2023 01:28 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 3B/E | ChinaSat 6E', 'Date': 'Thu Nov 09, 2023 11:23 UTC', 'Location': 'LC-2, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.15'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-27', 'Date': 'Wed Nov 08, 2023 05:05 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-26', 'Date': 'Sat Nov 04, 2023 00:37 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 7A | TJSW-10', 'Date': 'Fri Nov 03, 2023 14:54 UTC', 'Location': 'LC-201, Wenchang Space Launch Site, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'SpaceShipTwo | Galactic-05', 'Date': 'Thu Nov 02, 2023 15:44 UTC', 'Location': 'VMS Eve, Spaceport America, New Mexico, USA', 'Mission Status': 'Success', 'Organization': 'Virgin Galactic', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Long March 6A | Tianhui 5', 'Date': 'Tue Oct 31, 2023 22:50 UTC', 'Location': 'LC-9A, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-25', 'Date': 'Mon Oct 30, 2023 23:20 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-6', 'Date': 'Sun Oct 29, 2023 09:00 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1b | Cosmos 2570', 'Date': 'Fri Oct 27, 2023 06:04 UTC', 'Location': 'Site 43/3, Plesetsk Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'VKS RF', 'Rocket Status': 'Active', 'Price': '20.0'}
# {'Space Mission': 'Long March 2F/G | Shenzhou 17', 'Date': 'Thu Oct 26, 2023 03:14 UTC', 'Location': 'Site 901 (SLS-1), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Long March 2D | Yaogan 39 Group 04', 'Date': 'Mon Oct 23, 2023 20:03 UTC', 'Location': 'LC-3, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-24', 'Date': 'Sun Oct 22, 2023 02:17 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-5', 'Date': 'Sat Oct 21, 2023 08:23 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-23', 'Date': 'Wed Oct 18, 2023 00:39 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2D | Yunhai-1 04', 'Date': 'Sun Oct 15, 2023 00:54 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-22', 'Date': 'Fri Oct 13, 2023 23:01 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon Heavy | Psyche', 'Date': 'Fri Oct 13, 2023 14:19 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '97.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-4', 'Date': 'Mon Oct 09, 2023 07:43 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Vega | THEOS-2, TRITON & SSMS n°5', 'Date': 'Mon Oct 09, 2023 01:36 UTC', 'Location': 'ELV-1, Guiana Space Centre, French Guiana, France', 'Mission Status': 'Success', 'Organization': 'Arianespace', 'Rocket Status': 'Active', 'Price': '37.0'}
# {'Space Mission': 'Atlas V 501 | Project Kuiper Protoflight', 'Date': 'Fri Oct 06, 2023 18:06 UTC', 'Location': 'SLC-41, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'ULA', 'Rocket Status': 'Active', 'Price': '120.0'}
# {'Space Mission': 'SpaceShipTwo | Galactic-04', 'Date': 'Fri Oct 06, 2023 16:10 UTC', 'Location': 'VMS Eve, Spaceport America, New Mexico, USA', 'Mission Status': 'Success', 'Organization': 'Virgin Galactic', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-21', 'Date': 'Thu Oct 05, 2023 05:36 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2D | Yaogan 39 Group 03', 'Date': 'Thu Oct 05, 2023 00:24 UTC', 'Location': 'LC-3, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-19', 'Date': 'Sat Sep 30, 2023 02:00 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Qased | Nour 3', 'Date': 'Wed Sep 27, 2023 06:00 UTC', 'Location': 'Launch Platform, Shahrud Missile Test Site, Iran', 'Mission Status': 'Success', 'Organization': 'IRGC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Long March 4C | Yaogan 33-04', 'Date': 'Tue Sep 26, 2023 20:15 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '64.68'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-3', 'Date': 'Mon Sep 25, 2023 08:48 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-18', 'Date': 'Sun Sep 24, 2023 03:38 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Ceres-1 | Autumn Sonata', 'Date': 'Thu Sep 21, 2023 04:59 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Failure', 'Organization': 'Galactic Energy', 'Rocket Status': 'Active', 'Price': '4.9'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-17', 'Date': 'Wed Sep 20, 2023 03:38 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Electron/Curie | We Will Never Desert You', 'Date': 'Tue Sep 19, 2023 06:55 UTC', 'Location': 'Rocket Lab LC-1B, Māhia Peninsula, New Zealand', 'Mission Status': 'Failure', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'Long March 2D | Yaogan 39 Group 02', 'Date': 'Sun Sep 17, 2023 04:13 UTC', 'Location': 'LC-3, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-16', 'Date': 'Sat Sep 16, 2023 03:38 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1a | Soyuz MS-24', 'Date': 'Fri Sep 15, 2023 15:44 UTC', 'Location': 'Site 31/6, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '17.42'}
# {'Space Mission': 'Alpha | VICTUS NOX (TacRS-3)', 'Date': 'Fri Sep 15, 2023 02:28 UTC', 'Location': 'SLC-2W, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'Firefly', 'Rocket Status': 'Active', 'Price': '15.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-2', 'Date': 'Tue Sep 12, 2023 06:57 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Atlas V 551 | SILENTBARKER (NROL-107)', 'Date': 'Sun Sep 10, 2023 12:47 UTC', 'Location': 'SLC-41, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'ULA', 'Rocket Status': 'Active', 'Price': '153.0'}
# {'Space Mission': 'Long March 6A | Yaogan 40', 'Date': 'Sun Sep 10, 2023 04:30 UTC', 'Location': 'LC-9A, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-14', 'Date': 'Sat Sep 09, 2023 03:12 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'SpaceShipTwo | Galactic-03', 'Date': 'Fri Sep 08, 2023 15:22 UTC', 'Location': 'VMS Eve, Spaceport America, New Mexico, USA', 'Mission Status': 'Success', 'Organization': 'Virgin Galactic', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'H-IIA 202 | SLIM & XRISM', 'Date': 'Wed Sep 06, 2023 23:42 UTC', 'Location': 'LA-Y1, Tanegashima Space Center, Japan', 'Mission Status': 'Success', 'Organization': 'MHI', 'Rocket Status': 'Active', 'Price': '90.0'}
# {'Space Mission': 'Long March 4C | Yaogan 33-03', 'Date': 'Wed Sep 06, 2023 18:14 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '64.68'}
# {'Space Mission': 'Ceres-1S | The Little Mermaid', 'Date': 'Tue Sep 05, 2023 09:34 UTC', 'Location': 'DeFu-15002 Barge, Chinese Coastal Waters', 'Mission Status': 'Success', 'Organization': 'Galactic Energy', 'Rocket Status': 'Active', 'Price': '4.9'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-12', 'Date': 'Mon Sep 04, 2023 02:47 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Transport & Tracking Layer (Tranche 0, Flight 2)', 'Date': 'Sat Sep 02, 2023 14:25 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'PSLV-XL | Aditya L1', 'Date': 'Sat Sep 02, 2023 06:20 UTC', 'Location': 'Second Launch Pad, Satish Dhawan Space Centre, India', 'Mission Status': 'Success', 'Organization': 'ISRO', 'Rocket Status': 'Active', 'Price': '31.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-13', 'Date': 'Fri Sep 01, 2023 02:21 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2D | Yaogan 39 Group 01', 'Date': 'Thu Aug 31, 2023 07:36 UTC', 'Location': 'LC-3, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-11', 'Date': 'Sun Aug 27, 2023 01:05 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | SpaceX Crew-7', 'Date': 'Sat Aug 26, 2023 07:27 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Ceres-1 | Cornfield Chase', 'Date': 'Fri Aug 25, 2023 04:59 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'Galactic Energy', 'Rocket Status': 'Active', 'Price': '4.9'}
# {'Space Mission': 'Electron/Curie | We Love the Nightlife', 'Date': 'Wed Aug 23, 2023 23:45 UTC', 'Location': 'Rocket Lab LC-1B, Māhia Peninsula, New Zealand', 'Mission Status': 'Success', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'Chŏllima 1 | Manligyeong 1 #2', 'Date': 'Wed Aug 23, 2023 18:50 UTC', 'Location': 'Pad 2, Sohae Satellite Launching Station, North Korea', 'Mission Status': 'Failure', 'Organization': 'NADA', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Soyuz 2.1a | Progress MS-24', 'Date': 'Wed Aug 23, 2023 01:08 UTC', 'Location': 'Site 31/6, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '17.42'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 7-1', 'Date': 'Tue Aug 22, 2023 09:37 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 4C | Gaofen-12 04', 'Date': 'Sun Aug 20, 2023 17:45 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '64.68'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-10', 'Date': 'Thu Aug 17, 2023 03:36 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Kuaizhou 1A | HEAD-3A/B/C/D/E', 'Date': 'Mon Aug 14, 2023 05:32 UTC', 'Location': 'Mobile Launcher Pad, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASIC', 'Rocket Status': 'Active', 'Price': '5.8'}
# {'Space Mission': 'Long March 3B/E | L-SAR4-01 (LTDC-4A)', 'Date': 'Sat Aug 12, 2023 17:26 UTC', 'Location': 'LC-2, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.15'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-9', 'Date': 'Fri Aug 11, 2023 05:17 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1b/Fregat-M | Luna 25', 'Date': 'Thu Aug 10, 2023 23:10 UTC', 'Location': 'Site 1S, Vostochny Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '25.0'}
# {'Space Mission': 'SpaceShipTwo | Galactic 02', 'Date': 'Thu Aug 10, 2023 15:17 UTC', 'Location': 'VMS Eve, Spaceport America, New Mexico, USA', 'Mission Status': 'Success', 'Organization': 'Virgin Galactic', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Ceres-1 | Lucky 7', 'Date': 'Thu Aug 10, 2023 04:03 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'Galactic Energy', 'Rocket Status': 'Active', 'Price': '4.9'}
# {'Space Mission': 'Long March 2C | 5 m S-SAR-02 (Huanjing-2F)', 'Date': 'Tue Aug 08, 2023 22:53 UTC', 'Location': 'LC-9, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.8'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-20', 'Date': 'Tue Aug 08, 2023 03:57 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1b/Fregat-M | Cosmos 2569', 'Date': 'Mon Aug 07, 2023 13:20 UTC', 'Location': 'Site 43/3, Plesetsk Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'VKS RF', 'Rocket Status': 'Active', 'Price': '25.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-8', 'Date': 'Mon Aug 07, 2023 02:41 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Galaxy 37', 'Date': 'Thu Aug 03, 2023 05:00 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 4C | Fengyun-3F', 'Date': 'Thu Aug 03, 2023 03:47 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '64.68'}
# {'Space Mission': 'Antares 230+ | CRS NG-19', 'Date': 'Wed Aug 02, 2023 00:31 UTC', 'Location': 'LP-0A, Wallops Flight Facility, Virginia, USA', 'Mission Status': 'Success', 'Organization': 'Northrop', 'Rocket Status': 'Retired', 'Price': '85.0'}
# {'Space Mission': 'PSLV-CA | DS-SAR', 'Date': 'Sun Jul 30, 2023 01:01 UTC', 'Location': 'First Launch Pad, Satish Dhawan Space Centre, India', 'Mission Status': 'Success', 'Organization': 'ISRO', 'Rocket Status': 'Active', 'Price': '21.0'}
# {'Space Mission': 'Falcon Heavy | EchoStar 24 (Jupiter 3)', 'Date': 'Sat Jul 29, 2023 03:04 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '97.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-7', 'Date': 'Fri Jul 28, 2023 04:01 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2D | Yaogan 36 Group 05', 'Date': 'Wed Jul 26, 2023 20:02 UTC', 'Location': 'LC-3, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-6', 'Date': 'Mon Jul 24, 2023 00:50 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2D | Skysight AS-01 to 03 & Lingxi-03', 'Date': 'Sun Jul 23, 2023 02:50 UTC', 'Location': 'LC-9, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Ceres-1 | Lemon Tree', 'Date': 'Sat Jul 22, 2023 05:07 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'Galactic Energy', 'Rocket Status': 'Active', 'Price': '4.9'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-15', 'Date': 'Thu Jul 20, 2023 04:09 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Kuaizhou 1A | Tianmu-1 07-10', 'Date': 'Thu Jul 20, 2023 03:20 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASIC', 'Rocket Status': 'Active', 'Price': '5.8'}
# {'Space Mission': 'Electron/Curie | Baby Come Back', 'Date': 'Tue Jul 18, 2023 01:27 UTC', 'Location': 'Rocket Lab LC-1B, Māhia Peninsula, New Zealand', 'Mission Status': 'Success', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-15', 'Date': 'Sun Jul 16, 2023 03:50 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'LVM-3 | Chandrayaan-3', 'Date': 'Fri Jul 14, 2023 09:05 UTC', 'Location': 'Second Launch Pad, Satish Dhawan Space Centre, India', 'Mission Status': 'Success', 'Organization': 'ISRO', 'Rocket Status': 'Active', 'Price': '62.0'}
# {'Space Mission': 'ZhuQue-2 | Flight 2', 'Date': 'Wed Jul 12, 2023 01:00 UTC', 'Location': 'Site 96, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'Landspace', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-5', 'Date': 'Mon Jul 10, 2023 03:58 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2C/YZ-1S | 2 x SatNet test satellites', 'Date': 'Sun Jul 09, 2023 11:00 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.8'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-13', 'Date': 'Fri Jul 07, 2023 19:29 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Ariane 5 ECA | Syracuse 4B & Heinrich Hertz', 'Date': 'Wed Jul 05, 2023 22:00 UTC', 'Location': 'ELA-3, Guiana Space Centre, French Guiana, France', 'Mission Status': 'Success', 'Organization': 'Arianespace', 'Rocket Status': 'Retired', 'Price': '200.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Euclid Telescope', 'Date': 'Sat Jul 01, 2023 15:12 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'SpaceShipTwo | Galactic 01', 'Date': 'Thu Jun 29, 2023 15:28 UTC', 'Location': 'VMS Eve, Spaceport America, New Mexico, USA', 'Mission Status': 'Success', 'Organization': 'Virgin Galactic', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Soyuz 2.1b/Fregat-M | Meteor-M n°2-3 and others', 'Date': 'Tue Jun 27, 2023 11:34 UTC', 'Location': 'Site 1S, Vostochny Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '25.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-12', 'Date': 'Fri Jun 23, 2023 15:35 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Delta IV Heavy | NROL-68 (USA-345)', 'Date': 'Thu Jun 22, 2023 09:18 UTC', 'Location': 'SLC-37B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'ULA', 'Rocket Status': 'Active', 'Price': '350.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-7', 'Date': 'Thu Jun 22, 2023 07:19 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 6 | Shiyan 25', 'Date': 'Tue Jun 20, 2023 03:18 UTC', 'Location': 'LC-16, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '19.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Satria', 'Date': 'Sun Jun 18, 2023 22:21 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': "Electron | Scout's Arrow", 'Date': 'Sun Jun 18, 2023 01:24 UTC', 'Location': 'Rocket Lab LC-2 (LP-0C), Wallops Flight Facility, Virginia, USA', 'Mission Status': 'Success', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'Long March 2D | 41 x Jilin-1', 'Date': 'Thu Jun 15, 2023 05:30 UTC', 'Location': 'LC-9, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Transporter 8', 'Date': 'Mon Jun 12, 2023 21:35 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-11', 'Date': 'Mon Jun 12, 2023 07:10 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Kuaizhou 1A | Longjiang 3', 'Date': 'Fri Jun 09, 2023 02:35 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'ExPace', 'Rocket Status': 'Active', 'Price': '5.8'}
# {'Space Mission': 'Kinetica 1 | Second Flight', 'Date': 'Wed Jun 07, 2023 04:10 UTC', 'Location': 'Site 130, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CAS Space', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | CRS SpX-28', 'Date': 'Mon Jun 05, 2023 15:47 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-4', 'Date': 'Sun Jun 04, 2023 12:20 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 2-10', 'Date': 'Wed May 31, 2023 06:02 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Chŏllima 1 | Manligyeong 1 #1', 'Date': 'Tue May 30, 2023 21:27 UTC', 'Location': 'Pad 2, Sohae Satellite Launching Station, North Korea', 'Mission Status': 'Failure', 'Organization': 'NADA', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Long March 2F/G | Shenzhou 16', 'Date': 'Tue May 30, 2023 01:31 UTC', 'Location': 'Site 901 (SLS-1), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'GSLV Mk II | NVS-01 (IRNSS-1J)', 'Date': 'Mon May 29, 2023 05:12 UTC', 'Location': 'Second Launch Pad, Satish Dhawan Space Centre, India', 'Mission Status': 'Success', 'Organization': 'ISRO', 'Rocket Status': 'Active', 'Price': '47.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Arabsat 7B (Badr 8)', 'Date': 'Sat May 27, 2023 04:30 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1a/Fregat-M | Kondor-FKA n°1', 'Date': 'Fri May 26, 2023 21:14 UTC', 'Location': 'Site 1S, Vostochny Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '23.0'}
# {'Space Mission': 'Electron/Curie | TROPICS Flight 3: Coming to a Storm Near You', 'Date': 'Fri May 26, 2023 03:46 UTC', 'Location': 'Rocket Lab LC-1B, Māhia Peninsula, New Zealand', 'Mission Status': 'Success', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'SpaceShipTwo | Unity 25', 'Date': 'Thu May 25, 2023 16:23 UTC', 'Location': 'VMS Eve, Spaceport America, New Mexico, USA', 'Mission Status': 'Success', 'Organization': 'Virgin Galactic', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'KSLV-2 | NEXTSat-2 & Others', 'Date': 'Thu May 25, 2023 09:24 UTC', 'Location': 'LC-2, Naro Space Center, South Korea', 'Mission Status': 'Success', 'Organization': 'KARI', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Soyuz 2.1a | Progress MS-23', 'Date': 'Wed May 24, 2023 12:56 UTC', 'Location': 'Site 31/6, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '17.42'}
# {'Space Mission': 'Falcon 9 Block 5 | Axiom Mission 2 (Ax-2)', 'Date': 'Sun May 21, 2023 21:37 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2C | MUST-1A/B & Luojia-2 01', 'Date': 'Sun May 21, 2023 08:00 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.8'}
# {'Space Mission': 'Falcon 9 Block 5 | Iridium-9 & OneWeb #19', 'Date': 'Sat May 20, 2023 13:16 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-3', 'Date': 'Fri May 19, 2023 06:19 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 3B/E | Beidou-3 G4', 'Date': 'Wed May 17, 2023 02:49 UTC', 'Location': 'LC-2, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.15'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-9', 'Date': 'Sun May 14, 2023 05:03 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 2-9', 'Date': 'Wed May 10, 2023 20:09 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 7 | Tianzhou 6', 'Date': 'Wed May 10, 2023 13:22 UTC', 'Location': 'LC-201, Wenchang Space Launch Site, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Electron/Curie | TROPICS Flight 2: Rocket Like A Hurricane', 'Date': 'Mon May 08, 2023 01:00 UTC', 'Location': 'Rocket Lab LC-1B, Māhia Peninsula, New Zealand', 'Mission Status': 'Success', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-6', 'Date': 'Thu May 04, 2023 07:31 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon Heavy | ViaSat-3 Americas & Others', 'Date': 'Mon May 01, 2023 00:26 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '97.0'}
# {'Space Mission': 'Falcon 9 Block 5 | O3b mPOWER 3 & 4', 'Date': 'Fri Apr 28, 2023 22:12 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 3-5', 'Date': 'Thu Apr 27, 2023 13:40 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'SpaceShipTwo | Unity 24', 'Date': 'Wed Apr 26, 2023 13:47 UTC', 'Location': 'VMS Eve, Spaceport America, New Mexico, USA', 'Mission Status': 'Success', 'Organization': 'Virgin Galactic', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'PSLV-CA | TeLEOS-2 & Others', 'Date': 'Sat Apr 22, 2023 08:50 UTC', 'Location': 'First Launch Pad, Satish Dhawan Space Centre, India', 'Mission Status': 'Success', 'Organization': 'ISRO', 'Rocket Status': 'Active', 'Price': '21.0'}
# {'Space Mission': 'Starship-Super Heavy (Prototype) | Starship Flight Test', 'Date': 'Thu Apr 20, 2023 13:33 UTC', 'Location': 'Orbital Launch Pad A, Starbase, Texas, USA', 'Mission Status': 'Failure', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-2', 'Date': 'Wed Apr 19, 2023 14:31 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 4B | Fengyun-3G', 'Date': 'Sun Apr 16, 2023 01:36 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '64.68'}
# {'Space Mission': 'Falcon 9 Block 5 | Transporter 7', 'Date': 'Sat Apr 15, 2023 06:48 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Ariane 5 ECA | JUICE (Jupiter Icy Moons Explorer)', 'Date': 'Fri Apr 14, 2023 12:14 UTC', 'Location': 'ELA-3, Guiana Space Centre, French Guiana, France', 'Mission Status': 'Success', 'Organization': 'Arianespace', 'Rocket Status': 'Retired', 'Price': '200.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Intelsat 40e/TEMPO', 'Date': 'Fri Apr 07, 2023 04:30 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Hyperbola-1 | Dummy Payload', 'Date': 'Fri Apr 07, 2023 04:00 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'i-Space', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Falcon 9 Block 5 | Transport & Tracking Layer (Tranche 0, Flight 1)', 'Date': 'Sun Apr 02, 2023 14:29 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Tianlong-2 | Demo Flight', 'Date': 'Sun Apr 02, 2023 08:48 UTC', 'Location': 'Site 120, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'Space Pioneer', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Long March 4C | Yaogan 34-04', 'Date': 'Fri Mar 31, 2023 06:27 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '64.68'}
# {'Space Mission': 'Long March 2D | PIESAT-1 x 4', 'Date': 'Thu Mar 30, 2023 10:50 UTC', 'Location': 'LC-9, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.75'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-10', 'Date': 'Wed Mar 29, 2023 20:01 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Soyuz 2.1v | Cosmos 2568', 'Date': 'Wed Mar 29, 2023 19:57 UTC', 'Location': 'Site 43/4, Plesetsk Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'VKS RF', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'Shavit-2 | Ofek-13', 'Date': 'Tue Mar 28, 2023 23:10 UTC', 'Location': 'Pad 1, Palmachim Airbase, Israel', 'Mission Status': 'Success', 'Organization': 'IAI', 'Rocket Status': 'Active', 'Price': None}
# {'Space Mission': 'LVM-3 | OneWeb #18', 'Date': 'Sun Mar 26, 2023 03:30 UTC', 'Location': 'Second Launch Pad, Satish Dhawan Space Centre, India', 'Mission Status': 'Success', 'Organization': 'ISRO', 'Rocket Status': 'Active', 'Price': '62.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 5-5', 'Date': 'Fri Mar 24, 2023 15:43 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Electron/Curie | The Beat Goes On', 'Date': 'Fri Mar 24, 2023 09:14 UTC', 'Location': 'Rocket Lab LC-1B, Māhia Peninsula, New Zealand', 'Mission Status': 'Success', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'Soyuz 2.1a | Cosmos 2567', 'Date': 'Thu Mar 23, 2023 06:40 UTC', 'Location': 'Site 43/3, Plesetsk Cosmodrome, Russia', 'Mission Status': 'Success', 'Organization': 'VKS RF', 'Rocket Status': 'Active', 'Price': '17.42'}
# {'Space Mission': 'Terran 1 | Good Luck, Have Fun', 'Date': 'Thu Mar 23, 2023 03:25 UTC', 'Location': 'LC-16, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'Relativity Space', 'Rocket Status': 'Retired', 'Price': '12.0'}
# {'Space Mission': 'Kuaizhou 1A | Tianmu-1 03-06', 'Date': 'Wed Mar 22, 2023 09:09 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'ExPace', 'Rocket Status': 'Active', 'Price': '5.8'}
# {'Space Mission': 'Falcon 9 Block 5 | SES-18 & SES-19', 'Date': 'Fri Mar 17, 2023 23:38 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 2-8', 'Date': 'Fri Mar 17, 2023 19:26 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 3B/E | Gaofen-13-02', 'Date': 'Fri Mar 17, 2023 08:33 UTC', 'Location': 'LC-2, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.15'}
# {'Space Mission': 'Electron/Curie | Stronger Together', 'Date': 'Thu Mar 16, 2023 22:38 UTC', 'Location': 'Rocket Lab LC-2 (LP-0C), Wallops Flight Facility, Virginia, USA', 'Mission Status': 'Success', 'Organization': 'Rocket Lab', 'Rocket Status': 'Active', 'Price': '7.5'}
# {'Space Mission': 'Long March 11 | Shiyan 19', 'Date': 'Wed Mar 15, 2023 11:41 UTC', 'Location': 'Site 95A, Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '5.3'}
# {'Space Mission': 'Falcon 9 Block 5 | CRS SpX-27', 'Date': 'Wed Mar 15, 2023 00:30 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2C | Horus 2', 'Date': 'Mon Mar 13, 2023 04:02 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.8'}
# {'Space Mission': 'Proton-M/Briz-M | Luch-5X (Olymp-K 2)', 'Date': 'Sun Mar 12, 2023 23:13 UTC', 'Location': 'Site 200/39, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'VKS RF', 'Rocket Status': 'Active', 'Price': '65.0'}
# {'Space Mission': 'Long March 4C | Tianhui-6 A/B', 'Date': 'Thu Mar 09, 2023 22:41 UTC', 'Location': 'LC-9, Taiyuan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '64.68'}
# {'Space Mission': 'Falcon 9 Block 5 | OneWeb #17', 'Date': 'Thu Mar 09, 2023 19:13 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'H3-22 | ALOS-3', 'Date': 'Tue Mar 07, 2023 01:37 UTC', 'Location': 'LA-Y2, Tanegashima Space Center, Japan', 'Mission Status': 'Failure', 'Organization': 'MHI', 'Rocket Status': 'Active', 'Price': '50.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 2-7', 'Date': 'Fri Mar 03, 2023 18:38 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | SpaceX Crew-6', 'Date': 'Thu Mar 02, 2023 05:34 UTC', 'Location': 'LC-39A, Kennedy Space Center, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 6-1', 'Date': 'Mon Feb 27, 2023 23:13 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Long March 2C | Horus 1', 'Date': 'Fri Feb 24, 2023 04:01 UTC', 'Location': 'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '30.8'}
# {'Space Mission': 'Soyuz 2.1a | Soyuz MS-23', 'Date': 'Fri Feb 24, 2023 00:24 UTC', 'Location': 'Site 31/6, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'Roscosmos', 'Rocket Status': 'Active', 'Price': '17.42'}
# {'Space Mission': 'Long March 3B/E | ChinaSat 26', 'Date': 'Thu Feb 23, 2023 11:49 UTC', 'Location': 'LC-2, Xichang Satellite Launch Center, China', 'Mission Status': 'Success', 'Organization': 'CASC', 'Rocket Status': 'Active', 'Price': '29.15'}
# {'Space Mission': 'Falcon 9 Block 5 | Inmarsat I-6 F2', 'Date': 'Sat Feb 18, 2023 03:59 UTC', 'Location': 'SLC-40, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# {'Space Mission': 'Falcon 9 Block 5 | Starlink Group 2-5', 'Date': 'Fri Feb 17, 2023 19:12 UTC', 'Location': 'SLC-4E, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'SpaceX', 'Rocket Status': 'Active', 'Price': '67.0'}
# ...
# {'Space Mission': 'Atlas-LV3 Agena-A | Samos 2', 'Date': 'Tue Jan 31, 1961 20:21 UTC', 'Location': 'SLC-3W, Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'General Dynamics', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Mercury-Redstone | Mercury-Redstone 2 (MR-2)', 'Date': 'Tue Jan 31, 1961 16:55 UTC', 'Location': 'LC-5, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'NASA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | 1K n°5 (Korabl-Sputnik 3)', 'Date': 'Thu Dec 22, 1960 07:45 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Failure', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-21 Agena-B | Discoverer 19', 'Date': 'Tue Dec 20, 1960 20:32 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Mercury-Redstone | Mercury-Redstone 1A (MR-1A)', 'Date': 'Mon Dec 19, 1960 16:15 UTC', 'Location': 'LC-5, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'NASA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-D Able | Pioneer P-31', 'Date': 'Thu Dec 15, 1960 09:10 UTC', 'Location': 'LC-12, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'General Dynamics', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-21 Agena-B | Discoverer 18', 'Date': 'Wed Dec 07, 1960 20:20 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Scout X-1 | Explorer (S-56)', 'Date': 'Sun Dec 04, 1960 21:14 UTC', 'Location': 'LA-3, Wallops Flight Facility, Virginia, USA', 'Mission Status': 'Failure', 'Organization': 'NASA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | Korabl-Sputnik 3', 'Date': 'Thu Dec 01, 1960 07:30 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM21 Ablestar | Transit 3A & GRAB-2', 'Date': 'Wed Nov 30, 1960 19:50 UTC', 'Location': 'SLC-17B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-19 Delta | TIROS-2', 'Date': 'Wed Nov 23, 1960 11:13 UTC', 'Location': 'SLC-17A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Mercury-Redstone | Mercury-Redstone 1 (MR-1)', 'Date': 'Mon Nov 21, 1960 14:00 UTC', 'Location': 'LC-5, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'NASA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-21 Agena-B | Discoverer 17', 'Date': 'Sat Nov 12, 1960 20:42 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Juno II | Explorer 8', 'Date': 'Thu Nov 03, 1960 05:23 UTC', 'Location': 'LC-26B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'ABMA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-21 Agena-B | Discoverer 16', 'Date': 'Wed Oct 26, 1960 20:26 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Molniya | 1M n°2 (Marsnik 2)', 'Date': 'Fri Oct 14, 1960 13:51 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Failure', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-LV3 Agena-A | Samos 1', 'Date': 'Tue Oct 11, 1960 20:33 UTC', 'Location': 'SLC-3W, Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'General Dynamics', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Molniya | 1M n°1 (Marsnik 1)', 'Date': 'Mon Oct 10, 1960 14:27 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Failure', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM21 Ablestar | Courier 1B', 'Date': 'Tue Oct 04, 1960 17:50 UTC', 'Location': 'SLC-17B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-D Able | Pioneer P-30', 'Date': 'Sun Sep 25, 1960 15:13 UTC', 'Location': 'LC-12, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'General Dynamics', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 15', 'Date': 'Tue Sep 13, 1960 22:13 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | Korabl-Sputnik 2', 'Date': 'Fri Aug 19, 1960 08:44 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM21 Ablestar | Courier 1A', 'Date': 'Thu Aug 18, 1960 19:58 UTC', 'Location': 'SLC-17B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 14', 'Date': 'Thu Aug 18, 1960 19:57 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-19 Delta | Echo 1A', 'Date': 'Fri Aug 12, 1960 09:39 UTC', 'Location': 'SLC-17A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 13', 'Date': 'Wed Aug 10, 1960 20:37 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-D Mercury | Mercury-Atlas 1 (MA-1)', 'Date': 'Fri Jul 29, 1960 13:13 UTC', 'Location': 'LC-14, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'NASA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | 1K n°2 (Korabl-Sputnik 2)', 'Date': 'Thu Jul 28, 1960 09:31 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Failure', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 12', 'Date': 'Wed Jun 29, 1960 22:00 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM21 Ablestar | Transit 2A & GRAB-1', 'Date': 'Wed Jun 22, 1960 05:54 UTC', 'Location': 'SLC-17B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-LV3 Agena-A | Midas 2', 'Date': 'Tue May 24, 1960 17:36 UTC', 'Location': 'LC-14, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'General Dynamics', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | Korabl-Sputnik 1', 'Date': 'Sun May 15, 1960 00:00 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-19 Delta | Echo 1', 'Date': 'Fri May 13, 1960 09:16 UTC', 'Location': 'SLC-17A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | E-3 n°3 (Luna-3)', 'Date': 'Sat Apr 16, 1960 16:07 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Failure', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 11', 'Date': 'Fri Apr 15, 1960 20:30 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | E-3 n°2 (Luna-3)', 'Date': 'Fri Apr 15, 1960 15:06 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Failure', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM21 Ablestar | Transit 1B', 'Date': 'Wed Apr 13, 1960 12:02 UTC', 'Location': 'SLC-17B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-18 Able-II | TIROS-1', 'Date': 'Fri Apr 01, 1960 11:40 UTC', 'Location': 'SLC-17A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Juno II | Explorer 8a', 'Date': 'Wed Mar 23, 1960 13:35 UTC', 'Location': 'LC-26B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'ABMA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-18 Able-IV | Pioneer 5', 'Date': 'Fri Mar 11, 1960 13:00 UTC', 'Location': 'SLC-17A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-LV3 Agena-A | Midas 1', 'Date': 'Fri Feb 26, 1960 17:25 UTC', 'Location': 'LC-14, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'General Dynamics', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 10', 'Date': 'Fri Feb 19, 1960 20:15 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 9', 'Date': 'Thu Feb 04, 1960 18:51 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-D Able | Pioneer P-3', 'Date': 'Thu Nov 26, 1959 07:26 UTC', 'Location': 'LC-14, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'General Dynamics', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 8', 'Date': 'Fri Nov 20, 1959 19:25 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 7', 'Date': 'Sat Nov 07, 1959 20:28 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Juno II | Explorer 7', 'Date': 'Tue Oct 13, 1959 15:30 UTC', 'Location': 'LC-5, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'ABMA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | Luna-3', 'Date': 'Sun Oct 04, 1959 00:43 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vanguard | Vanguard 3', 'Date': 'Fri Sep 18, 1959 05:20 UTC', 'Location': 'LC-18A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Partial Failure', 'Organization': 'US Navy', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-18 Able-II | Transit 1A', 'Date': 'Thu Sep 17, 1959 14:34 UTC', 'Location': 'SLC-17A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | Luna-2', 'Date': 'Sat Sep 12, 1959 06:39 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Success', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Atlas-D Mercury | Big Joe 1', 'Date': 'Wed Sep 09, 1959 08:19 UTC', 'Location': 'LC-14, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Partial Failure', 'Organization': 'NASA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 6', 'Date': 'Wed Aug 19, 1959 19:24 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Juno II | Beacon 2', 'Date': 'Sat Aug 15, 1959 00:31 UTC', 'Location': 'LC-26B, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'ABMA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 5', 'Date': 'Thu Aug 13, 1959 19:00 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor DM-18 Able-III | Explorer 6', 'Date': 'Fri Aug 07, 1959 14:24 UTC', 'Location': 'SLC-17A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Juno II | Explorer 6a', 'Date': 'Thu Jul 16, 1959 17:37 UTC', 'Location': 'LC-5, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'ABMA', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 4', 'Date': 'Thu Jun 25, 1959 22:47 UTC', 'Location': 'SLC-1E (75-3-5), Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vanguard | Vanguard SLV-6', 'Date': 'Mon Jun 22, 1959 20:16 UTC', 'Location': 'LC-18A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'US Navy', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vostok | E-1A n°1 (Luna-2)', 'Date': 'Thu Jun 18, 1959 08:08 UTC', 'Location': 'Site 1/5, Baikonur Cosmodrome, Kazakhstan', 'Mission Status': 'Failure', 'Organization': 'RVSN USSR', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 3', 'Date': 'Wed Jun 03, 1959 20:09 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Failure', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Vanguard | Vanguard SLV-5', 'Date': 'Tue Apr 14, 1959 02:49 UTC', 'Location': 'LC-18A, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Failure', 'Organization': 'US Navy', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Thor-DM18 Agena-A | Discoverer 2', 'Date': 'Mon Apr 13, 1959 21:18 UTC', 'Location': 'SLC-1W (75-3-4), Vandenberg SFB, California, USA', 'Mission Status': 'Success', 'Organization': 'US Air Force', 'Rocket Status': 'Retired', 'Price': None}
# {'Space Mission': 'Juno II | Pioneer 4', 'Date': 'Tue Mar 03, 1959 05:10 UTC', 'Location': 'LC-5, Cape Canaveral SFS, Florida, USA', 'Mission Status': 'Success', 'Organization': 'ABMA', 'Rocket Status': 'Retired', 'Price': None}

# %% [markdown]
# ## Explanation of Code

# %% [markdown]
# Data Collection Scope: I targeting a total of 221 pages on the website, each containing data for approximately 30 space missions.
#
# For scrapping I use, python's BeautifulSoup library and requests module for page access and data extraction.
#
# The code iterates through each of the 221 pages systematically by generating specific URLs.
# Utilizes the requests.get() method to access the HTML content of each page.
# BeautifulSoup parses the HTML content and targets specific HTML elements (such as mission names, launch dates, and locations) using various methods like soup.find_all() and item.getText().
#
# Once basic information is extracted, the code drills deeper into each mission's specific page by extracting the onclick attribute of buttons for additional details. This involves building the URL for each mission's page and accessing its HTML content.
#
# Within these individual mission pages, the code identifies and extracts more specific details such as mission status, organization involved, rocket status, and rocket price using methods like details_soup.find() and text parsing.
#
# The information extracted from each mission's page is structured into dictionaries (result_dict) to organize related details for each mission. The data is then appended to results_list and merged with the corresponding basic mission information gathered earlier.
#
#
# Finally, the collected and structured data is written into a CSV file named "Space_Missions.csv." This file serves as an organized repository of extensive space mission details for subsequent analysis or reference.
#
# This web scraping code systematically navigates through multiple web pages, extracts specific details from each page, structures the data, and consolidates it into a structured CSV file for further analysis or use.
